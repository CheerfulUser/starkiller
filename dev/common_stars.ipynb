# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import pandas as pd
# %matplotlib notebook

# %%
files = glob('/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/*.gz')

# %%
pd.read_csv(/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/*.gz)
# Out:
#         1.17576E-05
# 0          0.000011
# 1          0.000011
# 2          0.000012
# 3          0.000012
# 4          0.000011
# ...             ...
# 100718    50.419400
# 100719    50.105400
# 100720    44.921500
# 100721    44.397700
# 100722    48.471000
#
# [100723 rows x 1 columns]

# %%
b = pd.read_csv('/Users/rri38/Documents/work/code/cube_scene/cuber/data/ck04_stsci/ckp00_3750_g45.dat.gz',delimiter=' ')

# %%
files
# Out:
# ['/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/p3800_g+5.0_m0.0_t02_st_z+0.50_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.flx.gz',
#  '/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/s4500_g+1.5_m1.0_t02_st_z-0.50_a+0.20_c+0.00_n+0.00_o+0.20_r+0.00_s+0.00.flx.gz',
#  '/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/s3900_g+0.0_m1.0_t02_st_z+0.00_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.flx.gz',
#  '/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/s4250_g+1.5_m1.0_t02_st_z-0.50_a+0.20_c+0.00_n+0.00_o+0.20_r+0.00_s+0.00.flx.gz',
#  '/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/s3800_g+0.5_m1.0_t02_st_z+0.50_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.flx.gz',
#  '/Users/rri38/Documents/work/code/cube_scene/cuber/data/common_stars/p4250_g+4.5_m0.0_t02_st_z-0.50_a+0.20_c+0.00_n+0.00_o+0.20_r+0.00_s+0.00.flx.gz',
# ...

# %%
a = np.loadtxt(files[0])

# %%
plt.figure()
plt.plot(np.arange(0,len(a)),a/np.nanmax(a))
plt.plot(b.wave,b.flux/np.nanmax(b.flux.values))
# Out:
# <img src="data:image/png;base64,..." width="640">
